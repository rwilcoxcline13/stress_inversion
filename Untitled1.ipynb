# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
test = np.loadtxt('stress_params.txt', delimiter=',')

# %%
print(np.shape(test))
# Out:
# (100000, 17)

# %%
plt.hist(test[:, 3], bins = 100)
plt.show()
